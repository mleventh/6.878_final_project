# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import pandas as pd
import os
import numpy as np
from sklearn.metrics import log_loss,roc_curve,auc
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.autograd as autograd
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pickle

# %%
input_filename="training_formatted_11_18_even_smaller.txt"

np.random.seed(0)
# 10 folds
k=10

cs=pd.read_csv(input_filename,sep='\t')
features=["mean_exp","damaging_ratio","non_damaging_ratio","n_male","n_female","n_COSMIC","n_TCGA"]
#features=["mean_exp","damaging_ratio","n_TCGA","n_female","n_COSMIC"]

#shuffle training and holdout data
cs=cs.sample(frac=1,random_state=1)
cs.reset_index(inplace=True)

cs_holdout=cs.sample(frac=0.1,random_state=1)

cs_prep=cs.loc[~cs.index.isin(cs_holdout.index),:]
cs_prep.reset_index(inplace=True)
cs_holdout.reset_index(inplace=True)

cs_k_fold=np.array_split(cs_prep,k)
cs_valid=pd.DataFrame()

for fold in range(k):
    cs_train=pd.DataFrame()
    TP=0
    FP=0
    FN=0
    TN=0
    
    #iterate through fold
    for number,group in enumerate(cs_k_fold):
        if fold==number:
            cs_valid=group
        else:
            cs_train=cs_train.append(group)
        
    cs_train=cs_train.reset_index(drop=True)
    cs_valid=cs_valid.reset_index(drop=True)

    clf = RandomForestClassifier(n_jobs=2, random_state=0)

    clf.fit(cs_train[features], cs_train['sig_dep'])
    print(clf.feature_importances_)
    
    base_X=clf.predict(cs_valid[features])
    
    for i in np.arange(0,len(base_X)):
        if base_X[i]==cs_valid.loc[i,'sig_dep'] and cs_valid.loc[i,'sig_dep']==1:
            TP+=1
        elif base_X[i]==cs_valid.loc[i,'sig_dep'] and cs_valid.loc[i,'sig_dep']==0:
            TN+=1
        elif base_X[i]!=cs_valid.loc[i,'sig_dep'] and cs_valid.loc[i,'sig_dep']==1:
            FN+=1
        elif base_X[i]!=cs_valid.loc[i,'sig_dep'] and cs_valid.loc[i,'sig_dep']==0:
            FP+=1
            
    acc=(TP+TN)/len(base_X)
    
    tpr=TP/(TP+FN)
    fpr=FP/(FP+TN)
    specificity=TN/(TN+FP)
    print(["Accuracy: "+str(acc),"sensitivity: "+str(tpr),
           "specificity: "+str(specificity),"false positive rate: "+str(fpr)])
    
    #loss=log_loss(base_X,cs_valid['sig_dep'])
    #print(loss)
# Out:
# [0.19869312 0.11131072 0.13024673 0.1164839  0.06596101 0.16758383
#  0.20972069]
# ['Accuracy: 0.9024390243902439', 'sensitivity: 0.2', 'specificity: 1.0', 'false positive rate: 0.0']
# [0.20686588 0.12350651 0.11940814 0.09847597 0.0820642  0.1422364
#  0.2274429 ]
# ['Accuracy: 0.9024390243902439', 'sensitivity: 0.42857142857142855', 'specificity: 1.0', 'false positive rate: 0.0']
# [0.28017035 0.08562715 0.12052016 0.10554907 0.08824024 0.13990886
#  0.17998418]
# ['Accuracy: 0.975', 'sensitivity: 0.0', 'specificity: 1.0', 'false positive rate: 0.0']
# [0.23792979 0.10497551 0.12471576 0.08797842 0.07381684 0.16429711
#  0.20628657]
# ['Accuracy: 0.85', 'sensitivity: 0.25', 'specificity: 1.0', 'false positive rate: 0.0']
# [0.27681769 0.11123435 0.13751422 0.12807483 0.08191548 0.09215662
#  0.17228681]
# ['Accuracy: 0.95', 'sensitivity: 0.8', 'specificity: 0.9714285714285714', 'false positive rate: 0.02857142857142857']
# [0.26428796 0.10813498 0.10137136 0.08738724 0.07711569 0.09754034
#  0.26416244]
# ['Accuracy: 0.9', 'sensitivity: 0.2', 'specificity: 1.0', 'false positive rate: 0.0']
# [0.26668068 0.1026792  0.096615   0.10426109 0.11433971 0.08136651
#  0.23405781]
# ['Accuracy: 0.975', 'sensitivity: 0.6666666666666666', 'specificity: 1.0', 'false positive rate: 0.0']
# [0.2264734  0.07725486 0.11927345 0.10547567 0.12751961 0.11820727
#  0.22579574]
# ['Accuracy: 0.925', 'sensitivity: 0.0', 'specificity: 1.0', 'false positive rate: 0.0']
# [0.24995182 0.08893322 0.13660755 0.098667   0.11816503 0.09830494
#  0.20937044]
# ['Accuracy: 0.9', 'sensitivity: 0.6', 'specificity: 0.9428571428571428', 'false positive rate: 0.05714285714285714']
# [0.23610667 0.12064477 0.10196312 0.10543626 0.11181376 0.11032398
#  0.21371143]
# ['Accuracy: 0.975', 'sensitivity: 1.0', 'specificity: 0.972972972972973', 'false positive rate: 0.02702702702702703']

# %%
input_filename="training_formatted_11_18.txt"

np.random.seed(0)
# 10 folds
k=10

cs=pd.read_csv(input_filename,sep='\t')
features=["mean_exp","damaging_ratio","non_damaging_ratio","n_male","n_female","n_COSMIC","n_TCGA"]

#shuffle training and holdout data
cs=cs.sample(frac=1,random_state=1)
cs.reset_index(inplace=True)

cs_holdout=cs.sample(frac=0.1,random_state=1)

cs_prep=cs.loc[~cs.index.isin(cs_holdout.index),:]
cs_prep.reset_index(inplace=True)
cs_holdout.reset_index(inplace=True)

cs_k_fold=np.array_split(cs_prep,k)
cs_valid=pd.DataFrame()

for fold in range(k):
    cs_train=pd.DataFrame()
    TP=0
    FP=0
    FN=0
    TN=0
    
    #iterate through fold
    for number,group in enumerate(cs_k_fold):
        if fold==number:
            cs_valid=group
        else:
            cs_train=cs_train.append(group)
        
    cs_train=cs_train.reset_index(drop=True)
    cs_valid=cs_valid.reset_index(drop=True)

    clf = SVC(kernel='linear')
    y=pd.factorize(cs_train['sig_dep'])[0]

    clf.fit(cs_train[features], y)
    #print(clf.feature_importances_)
    
    base_X=clf.predict(cs_valid[features])
    
    for i in np.arange(0,len(base_X)):
        if base_X[i]==cs_valid.loc[i,'sig_dep'] and cs_valid.loc[i,'sig_dep']==1:
            TP+=1
        elif base_X[i]==cs_valid.loc[i,'sig_dep'] and cs_valid.loc[i,'sig_dep']==0:
            TN+=1
        elif base_X[i]!=cs_valid.loc[i,'sig_dep'] and cs_valid.loc[i,'sig_dep']==1:
            FN+=1
        elif base_X[i]!=cs_valid.loc[i,'sig_dep'] and cs_valid.loc[i,'sig_dep']==0:
            FP+=1
            
    acc=n_match/len(base_X)
    
    tpr=TP/(TP+FN)
    fpr=FP/(FP+TN)
    specificity=TN/(TN+FP)
    print([acc,tpr,specificity,fpr])
    
    #loss=log_loss(base_X,cs_valid['sig_dep'])
    #print(loss)
# Out:
# [0.9972565157750343, 0.0, 1.0, 0.0]
# [0.9986263736263736, 0.0, 1.0, 0.0]
# [0.9986263736263736, 0.0, 1.0, 0.0]
# [0.9986263736263736, 0.0, 1.0, 0.0]
# [0.9986263736263736, 0.0, 1.0, 0.0]
# [0.9986263736263736, 0.0, 1.0, 0.0]
# [0.9986263736263736, 0.0, 1.0, 0.0]
# [0.9986263736263736, 0.0, 1.0, 0.0]
# [0.9986263736263736, 0.0, 1.0, 0.0]
# [0.9986263736263736, 0.0, 1.0, 0.0]

# %%
class NNet(nn.Module):
    # use prior architectures. 
    def __init__(self): #self,n_input_features,hidden_size,n_layers
        super(NNet, self).__init__()
        self.fc1 = nn.Linear(6, 72)
        self.dropout = nn.Dropout(0.1) 
        self.fc2 = nn.Linear(72, 72)
        self.fc3 = nn.Linear(72,1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        x = self.dropout(self.relu(self.fc1(x))) 
        x = self.dropout(self.relu(self.fc2(x)))
        x = self.sigmoid(self.fc3(x))
        return x

# %%
class csDataset(Dataset):
    """call stat dataset."""

    def __init__(self, df, transform=None):
        """
        Args:
            tsv_file (string): Path to the tsv file with annotations.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.cs_frame = df
        self.transform = transform

    def __len__(self):
        return len(self.cs_frame)

    def __getitem__(self, idx):
        items=self.cs_frame.loc[idx,["damaging_ratio","non_damaging_ratio","n_male","n_female","n_COSMIC","n_TCGA"]]
        #items=self.cs_frame.loc[idx,["mean_exp","n_TCGA"]]
        features = torch.FloatTensor(items) 
        target = torch.FloatTensor(pd.Series(self.cs_frame.loc[idx,'sig_dep'],dtype=np.float32).values)
        sample = {'target':target,
            'features': features}

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
input_filename="training_formatted_11_18_even_smaller.txt"
k=10
error_tol=1e-4

cs=pd.read_csv(input_filename,sep='\t')
cs=cs.sample(frac=1,random_state=1)
cs.reset_index(inplace=True)

#cs_holdout=cs.sample(frac=0.1,random_state=1)

#cs_prep=cs.loc[~cs.index.isin(cs_holdout.index),:]
#cs_prep.reset_index(inplace=True)
#cs_holdout.reset_index(inplace=True)

cs_k_fold=np.array_split(cs,k)
cs_valid=pd.DataFrame()

performance_k=[]
acc_k=[]
spec_k=[]
sens_k=[]

for fold in range(k):
    
    net = NNet()

    criterion = nn.BCELoss() 
    plt.gcf().clear()
    
    optimizer = optim.Adam(net.parameters(), lr=0.01) # maybe replace with Adam
    cs_train=pd.DataFrame()

    
    for number,group in enumerate(cs_k_fold):
        if fold==number:
            cs_valid=group
        else:
            cs_train=cs_train.append(group)
        
    cs_train=cs_train.reset_index(drop=True)
    cs_valid=cs_valid.reset_index(drop=True)
    transformed_dataset = csDataset(df=cs_train)

    cs = DataLoader(transformed_dataset, batch_size=10,
                        shuffle=True, num_workers=10)

    acc=0
    tp=0
    fp=0
    fn=0
    tn=0
    for epoch in range(20):
        running_loss = 0.0
        net.train()

        for i, data in enumerate(cs):
            targets, inputs = data['target'],data['features']

            optimizer.zero_grad()
            outputs = net(inputs)

            loss = criterion(outputs,targets)

            running_loss += loss.item()
#             if 1 in targets:
#                 print([targets,outputs,epoch,i,loss.item()])
            
            loss.backward()

            optimizer.step()
            
            for j in range(len(outputs)):
                if targets[j]==0 and outputs[j]<0.5:
                    tn+=1
                    acc+=1
                elif targets[j]==0 and outputs[j]>=0.5:
                    fp+=1
                elif targets[j]==1 and outputs[j]<=0.5:
                    fn+=1
                elif targets[j]==1 and outputs[j]>0.5:
                    tp+=1
                    acc+=1
                
            accuracy=acc/(len(outputs)*(i+1)+epoch*len(cs_train.index))
            try:
                tpr=tp/(tp+fn)
                fpr=fp/(fp+tn)
                specificity=tn/(tn+fp)
            except ZeroDivisionError:
                pass
            
            if i%5==0:
                print([epoch,i])
                print("training accuracy: "+str(accuracy))
                print("training sensitivity: "+str(tpr))
                print("training specificity: "+str(specificity))

            if loss<error_tol and 1 in targets:
                break
        else:
            continue
        break
            
            
#             plt.scatter(i+(120*epoch),loss.item(),
#                 label='training' if i == 0 else "")
#             plt.xlabel('batch')
#             plt.ylabel('loss')
#         plt.savefig("loss_"+str(fold)+".png")
        
    #torch.save(net, "fold_dev")
            
    #eval_df=pd.DataFrame(columns=["pred","target"])        
    with torch.no_grad():
        
        transformed_dataset = csDataset(df=cs_valid)

        val = DataLoader(transformed_dataset, batch_size=10,
                        shuffle=True, num_workers=10)
        net.eval()
        shifts=[]
        baseline_shifts=[]
        valid_acc=[]
        valid_spec=[]
        valid_sens=[]
        plt.gcf().clear()
        
        acc=0
        tp=0
        fp=0
        fn=0
        tn=0
        for i, data in enumerate(val,0):
            
            targets,inputs=data['target'],data['features']
            
            outputs=net(inputs)

            loss = criterion(outputs,targets)

            shifts.append(loss.item())
            
#             print([outputs,targets])
#             plt.scatter(outputs,targets)
#             plt.xlabel('predicted_af')
#             plt.ylabel('target_af')

            running_loss += loss.item()
    
            for j in range(len(outputs)):
                if targets[j]==0 and outputs[j]<0.5:
                    tn+=1
                    acc+=1
                elif targets[j]==0 and outputs[j]>0.5:
                    fp+=1
                elif targets[j]==1 and outputs[j]<0.5:
                    fn+=1
                elif targets[j]==1 and outputs[j]>0.5:
                    tp+=1
                    acc+=1
            try:        
                tpr=tp/(tp+fn)
                fpr=fp/(fp+tn)
                specificity=tn/(tn+fp)
            except ZeroDivisionError:
                pass
            accuracy=acc/(len(outputs)*(i+1))
               
            valid_acc.append(accuracy)
            valid_sens.append(tpr)
            valid_spec.append(specificity)
#         plt.scatter(np.arange(0,len(shifts)),shifts,c='b',
#                     label='validation' if i == 0 else "")
#         plt.xlabel('batch')
#         plt.ylabel('loss') 
#         plt.savefig("loss_"+str(fold)+".png")
#         plt.gcf().clear()

        performance=np.median(shifts)
        print(np.median(shifts))
        
        perform_acc=np.median(valid_acc)
        perform_sens=np.median(valid_sens)
        perform_spec=np.median(valid_spec)

        performance_k.append(performance)
        acc_k.append(perform_acc)
        sens_k.append(perform_sens)
        spec_k.append(perform_spec)
        
        print(acc_k)
        print([np.median(performance_k),np.median(acc_k),np.median(sens_k),np.median(spec_k)])
# Out:
# [0, 0]
# training accuracy: 0.3
# training sensitivity: 0.30606860158311344
# training specificity: 0.9856817442238854
# [0, 5]
# training accuracy: 0.7666666666666667
# training sensitivity: 0.0
# training specificity: 0.8679245283018868
# [0, 10]
# training accuracy: 0.8090909090909091
# training sensitivity: 0.0
# training specificity: 0.9270833333333334
# [0, 15]
# training accuracy: 0.8375
# training sensitivity: 0.0
# training specificity: 0.950354609929078
# [0, 20]
# training accuracy: 0.8523809523809524
# training sensitivity: 0.1111111111111111
# training specificity: 0.9617486338797814
# [0, 25]
# training accuracy: 0.8615384615384616
# training sensitivity: 0.0967741935483871
# training specificity: 0.9650655021834061
# [0, 30]
# training accuracy: 0.867741935483871
# training sensitivity: 0.08333333333333333
# training specificity: 0.9708029197080292
# [0, 35]
# training accuracy: 0.875
# training sensitivity: 0.12195121951219512
# training specificity: 0.9717868338557993
# [0, 40]
# training accuracy: 4.341463414634147
# training sensitivity: 0.13953488372093023
# training specificity: 0.9749303621169917
# [1, 0]
# training accuracy: 0.8883495145631068
# training sensitivity: 0.13953488372093023
# training specificity: 0.975609756097561
# [1, 5]
# training accuracy: 0.8961038961038961
# training sensitivity: 0.15217391304347827
# training specificity: 0.9783653846153846
# [1, 10]
# training accuracy: 0.900390625
# training sensitivity: 0.17647058823529413
# training specificity: 0.9804772234273319
# [1, 15]
# training accuracy: 0.9039145907473309
# training sensitivity: 0.19642857142857142
# training specificity: 0.9822134387351779
# [1, 20]
# training accuracy: 0.9068627450980392
# training sensitivity: 0.21311475409836064
# training specificity: 0.9836660617059891
# [1, 25]
# training accuracy: 0.9078549848942599
# training sensitivity: 0.22727272727272727
# training specificity: 0.9832214765100671
# [1, 30]
# training accuracy: 0.9030898876404494
# training sensitivity: 0.22666666666666666
# training specificity: 0.9827315541601256
# [1, 35]
# training accuracy: 0.9068241469816273
# training sensitivity: 0.25
# training specificity: 0.9838709677419355
# [1, 40]
# training accuracy: 1.5020661157024793
# training sensitivity: 0.2558139534883721
# training specificity: 0.9818941504178273
# [2, 0]
# training accuracy: 0.902948402948403
# training sensitivity: 0.2696629213483146
# training specificity: 0.9806896551724138
# [2, 5]
# training accuracy: 0.9074074074074074
# training sensitivity: 0.2903225806451613
# training specificity: 0.9818417639429312
# [2, 10]
# training accuracy: 0.9080962800875274
# training sensitivity: 0.3137254901960784
# training specificity: 0.9827586206896551
# [2, 15]
# training accuracy: 0.9107883817427386
# training sensitivity: 0.3173076923076923
# training specificity: 0.9825581395348837
# [2, 20]
# training accuracy: 0.9112426035502958
# training sensitivity: 0.3181818181818182
# training specificity: 0.9834070796460177
# [2, 25]
# training accuracy: 0.9135338345864662
# training sensitivity: 0.32142857142857145
# training specificity: 0.9831932773109243
# [2, 30]
# training accuracy: 0.914721723518851
# training sensitivity: 0.3130434782608696
# training specificity: 0.983983983983984
# [2, 35]
# training accuracy: 0.9140893470790378
# training sensitivity: 0.3562753036437247
# training specificity: 0.9879401833092137
# [5, 35]
# training accuracy: 0.9215189873417722
# training sensitivity: 0.35856573705179284
# training specificity: 0.9882019820670127
# [5, 40]
# training accuracy: 1.0611854684512427
# training sensitivity: 0.35271317829457366
# training specificity: 0.9883936861652739
# [6, 0]
# training accuracy: 0.9203137902559868
# training sensitivity: 0.35384615384615387
# training specificity: 0.9884366327474561
# [6, 5]
# training accuracy: 0.9199029126213593
# training sensitivity: 0.34962406015037595
# training specificity: 0.9886672710788758
# [6, 10]
# training accuracy: 0.9191118160190325
# training sensitivity: 0.34798534798534797
# training specificity: 0.9884393063583815
# [6, 15]
# training accuracy: 0.9195178849144634
# training sensitivity: 0.35018050541516244
# training specificity: 0.9882352941176471
# [6, 20]
# training accuracy: 0.9187643020594966
# training sensitivity: 0.3473684210526316
# training specificity: 0.9884467265725289
# [6, 25]
# training accuracy: 0.9202844311377245
# training sensitivity: 0.3541666666666667
# training specificity: 0.9886744966442953
# [6, 30]
# training accuracy: 0.9206465833945628
# training sensitivity: 0.35494880546075086
# training specificity: 0.9888843145327295
# [6, 35]
# training accuracy: 0.9213564213564214
# training sensitivity: 0.35906040268456374
# training specificity: 0.9890864995957963
# [6, 40]
# training accuracy: 1.0400962309542903
# training sensitivity: 0.36212624584717606
# training specificity: 0.9888579387186629
# [7, 0]
# training accuracy: 0.9220963172804533
# training sensitivity: 0.36423841059602646
# training specificity: 0.9888977002379065
# [7, 5]
# training accuracy: 0.9220598469032707
# training sensitivity: 0.35947712418300654
# training specificity: 0.9890965732087228
# [7, 10]
# training accuracy: 0.9227086183310533
# training sensitivity: 0.3665594855305466
# training specificity: 0.9889016456180635
# [7, 15]
# training accuracy: 0.9226630800268998
# training sensitivity: 0.3659305993690852
# training specificity: 0.9890854347007904
# [7, 20]
# training accuracy: 0.923941798941799
# training sensitivity: 0.36990595611285265
# training specificity: 0.9892791127541589
# [7, 25]
# training accuracy: 0.9242029928432011
# training sensitivity: 0.367601246105919
# training specificity: 0.9891027969487831
# [7, 30]
# training accuracy: 0.9244558258642765
# training sensitivity: 0.37003058103975534
# training specificity: 0.9892742223811226
# [7, 35]
# training accuracy: 0.9240705734089477
# training sensitivity: 0.3701492537313433
# training specificity: 0.9894328989080662
# [7, 40]
# training accuracy: 1.025207182320442
# training sensitivity: 0.3691860465116279
# training specificity: 0.9895543175487466
# [8, 0]
# training accuracy: 0.9234345939243646
# training sensitivity: 0.3691860465116279
# training specificity: 0.9895905621096461
# [8, 5]
# training accuracy: 0.9236874236874237
# training sensitivity: 0.37142857142857144
# training specificity: 0.9897470950102529
# [8, 10]
# training accuracy: 0.9230306674684305
# training sensitivity: 0.3672316384180791
# training specificity: 0.9892328398384926
# [8, 15]
# training accuracy: 0.9235781990521327
# training sensitivity: 0.3697478991596639
# training specificity: 0.9890692282212653
# [8, 20]
# training accuracy: 0.9235259778166959
# training sensitivity: 0.3674033149171271
# training specificity: 0.9892297650130548
# [8, 25]
# training accuracy: 0.9237629459148446
# training sensitivity: 0.3712737127371274
# training specificity: 0.9893788220148053
# [8, 30]
# training accuracy: 0.923425978445831
# training sensitivity: 0.3696808510638298
# training specificity: 0.9895238095238095
# [8, 35]
# training accuracy: 0.9233780760626398
# training sensitivity: 0.37402597402597404
# training specificity: 0.9896584142901912
# [8, 40]
# training accuracy: 1.0136446331109763
# training sensitivity: 0.37467700258397935
# training specificity: 0.989786443825441
# [9, 0]
# training accuracy: 0.9242006615214995
# training sensitivity: 0.37628865979381443
# training specificity: 0.9898148148148148
# [9, 5]
# training accuracy: 0.9238716693855357
# training sensitivity: 0.37626262626262624
# training specificity: 0.9899451553930531
# [9, 10]
# training accuracy: 0.9246244635193133
# training sensitivity: 0.37844611528822053
# training specificity: 0.9900871132472214
# [9, 15]
# training accuracy: 0.9237691900476442
# training sensitivity: 0.375
# training specificity: 0.9902077151335311
# [9, 20]
# training accuracy: 0.9234587251828631
# training sensitivity: 0.37530266343825663
# training specificity: 0.9897510980966325
# [9, 25]
# training accuracy: 0.9239298607529655
# training sensitivity: 0.37889688249400477
# training specificity: 0.9895983819705287
# [9, 30]
# training accuracy: 0.9241344195519349
# training sensitivity: 0.37857142857142856
# training specificity: 0.9894526795895097
# [9, 35]
# training accuracy: 0.9245852187028658
# training sensitivity: 0.3811764705882353
# training specificity: 0.9895862651280608
# [9, 40]
# training accuracy: 1.0043243243243243
# training sensitivity: 0.37906976744186044
# training specificity: 0.9896935933147633
# [10, 0]
# training accuracy: 0.9240694789081886
# training sensitivity: 0.3787528868360277
# training specificity: 0.989713650264109
# [10, 5]
# training accuracy: 0.9237745098039216
# training sensitivity: 0.37727272727272726
# training specificity: 0.9898351648351649
# [10, 10]
# training accuracy: 0.9239709443099273
# training sensitivity: 0.3747178329571106
# training specificity: 0.9899647409818281
# [10, 15]
# training accuracy: 0.9239234449760766
# training sensitivity: 0.37555555555555553
# training specificity: 0.9900804289544236
# [10, 20]
# training accuracy: 0.9243498817966903
# training sensitivity: 0.378021978021978
# training specificity: 0.9901986754966887
# [10, 25]
# training accuracy: 0.9242990654205607
# training sensitivity: 0.3787878787878788
# training specificity: 0.9903090623363018
# [10, 30]
# training accuracy: 0.9244803695150116
# training sensitivity: 0.3763440860215054
# training specificity: 0.9904269081500647
# [10, 35]
# training accuracy: 0.9248858447488585
# training sensitivity: 0.3773987206823028
# training specificity: 0.9905395039631808
# [10, 40]
# training accuracy: 0.9975621647976597
# training sensitivity: 0.38054968287526425
# training specificity: 0.9906305393770575
# [11, 0]
# training accuracy: 0.9255415162454874
# training sensitivity: 0.38054968287526425
# training specificity: 0.9906542056074766
# [11, 5]
# training accuracy: 0.9257028112449799
# training sensitivity: 0.38204592901878914
# training specificity: 0.9907569323007744
# [11, 10]
# training accuracy: 0.925639894086496
# training sensitivity: 0.37888198757763975
# training specificity: 0.9908619412200543
# [11, 15]
# training accuracy: 0.9255783500654736
# training sensitivity: 0.3783231083844581
# training specificity: 0.9909601759100904
# [0.875]
# [0.1410168707370758, 0.875, 0.3333333333333333, 0.9259259259259259]
# [0, 0]
# training accuracy: 0.7
# training sensitivity: 0.0
# training specificity: 0.7777777777777778
# [0, 5]
# training accuracy: 0.8333333333333334
# training sensitivity: 0.0
# training specificity: 0.9615384615384616
# [0, 10]
# training accuracy: 0.8636363636363636
# training sensitivity: 0.0
# training specificity: 0.979381443298969
# [0, 15]
# training accuracy: 0.875
# training sensitivity: 0.0
# training specificity: 0.9859154929577465
# [0, 20]
# training accuracy: 0.9
# training sensitivity: 0.0
# training specificity: 0.9895287958115183
# [0, 25]
# training accuracy: 0.8961538461538462
# training sensitivity: 0.0
# training specificity: 0.9914893617021276
# [0, 30]
# training accuracy: 0.9032258064516129
# training sensitivity: 0.0
# training specificity: 0.9929078014184397
# [0, 35]
# training accuracy: 0.9027777777777778
# training sensitivity: 0.05714285714285714
# training specificity: 0.9938461538461538
# [0, 40]
# training accuracy: 4.439024390243903
# training sensitivity: 0.10256410256410256
# training specificity: 0.9917355371900827
# [1, 0]
# training accuracy: 0.9077669902912622
# training sensitivity: 0.10256410256410256
# training specificity: 0.9919571045576407
# [1, 5]
# training accuracy: 0.9155844155844156
# training sensitivity: 0.1
# training specificity: 0.9928909952606635
# [1, 10]
# training accuracy: 0.912109375
# training sensitivity: 0.1276595744680851
# training specificity: 0.9913978494623656
# [1, 15]
# training accuracy: 0.9074733096085409
# training sensitivity: 0.14545454545454545
# training specificity: 0.9901380670611439
# [1, 20]
# training accuracy: 0.9117647058823529
# training sensitivity: 0.14035087719298245
# training specificity: 0.990990990990991
# [1, 25]
# training accuracy: 0.9123867069486404
# training sensitivity: 0.22727272727272727
# training specificity: 0.988255033557047
# [1, 30]
# training accuracy: 0.9157303370786517
# training sensitivity: 0.2535211267605634
# training specificity: 0.9890795631825273
# [1, 35]
# training accuracy: 0.916010498687664
# training sensitivity: 0.25333333333333335
# training specificity: 0.9883551673944687
# [1, 40]
# training accuracy: 1.524793388429752
# training sensitivity: 0.2564102564102564
# training specificity: 0.9889807162534435
# [2, 0]
# training accuracy: 0.9176904176904177
# training sensitivity: 0.2625
# training specificity: 0.989100817438692
# [2, 5]
# training accuracy: 0.9189814814814815
# training sensitivity: 0.27380952380952384
# training specificity: 0.9884615384615385
# [2, 10]
# training accuracy: 0.9212253829321663
# training sensitivity: 0.27586206896551724
# training specificity: 0.9891172914147521
# [2, 15]
# training accuracy: 0.921161825726141
# training sensitivity: 0.27956989247311825
# training specificity: 0.9896670493685419
# [2, 20]
# training accuracy: 0.9211045364891519
# training sensitivity: 0.2736842105263158
# training specificity: 0.9880304678998912
# [2, 25]
# training accuracy: 0.9201127819548872
# training sensitivity: 0.27
# training specificity: 0.9875518672199171
# [2, 30]
# training accuracy: 0.9192100538599641
# training sensitivity: 0.28440366972477066
# training specificity: 0.9880597014925373
# [2, 35]
# training accuracy: 0.9209621993127147
# training sensitivity: 0.30434782608695654
# training specificity: 0.988560533841754
# [2, 40]
# [5, 35]
# training accuracy: 0.9274261603375528
# training sensitivity: 0.3624454148471616
# training specificity: 0.9878561419897244
# [5, 40]
# training accuracy: 1.0693116634799236
# training sensitivity: 0.36324786324786323
# training specificity: 0.9880624426078971
# [6, 0]
# training accuracy: 0.9277456647398844
# training sensitivity: 0.36324786324786323
# training specificity: 0.9881170018281535
# [6, 5]
# training accuracy: 0.9279935275080906
# training sensitivity: 0.36929460580912865
# training specificity: 0.9883460331689825
# [6, 10]
# training accuracy: 0.9282315622521808
# training sensitivity: 0.3780487804878049
# training specificity: 0.9876977152899824
# [6, 15]
# training accuracy: 0.9272939346811819
# training sensitivity: 0.3705179282868526
# training specificity: 0.9875053856096511
# [6, 20]
# training accuracy: 0.9263920671243325
# training sensitivity: 0.36923076923076925
# training specificity: 0.9877222692633362
# [6, 25]
# training accuracy: 0.9266467065868264
# training sensitivity: 0.37218045112781956
# training specificity: 0.9879467996674979
# [6, 30]
# training accuracy: 0.9272593681116826
# training sensitivity: 0.37407407407407406
# training specificity: 0.9881729200652528
# [6, 35]
# training accuracy: 0.9278499278499278
# training sensitivity: 0.375
# training specificity: 0.988
# [6, 40]
# training accuracy: 1.0477145148356055
# training sensitivity: 0.3772893772893773
# training specificity: 0.9878000787091696
# [7, 0]
# training accuracy: 0.9284702549575071
# training sensitivity: 0.3781818181818182
# training specificity: 0.9878383679874461
# [7, 5]
# training accuracy: 0.9290187891440501
# training sensitivity: 0.37906137184115524
# training specificity: 0.9876780901039661
# [7, 10]
# training accuracy: 0.9292065663474692
# training sensitivity: 0.3821428571428571
# training specificity: 0.9871406959152799
# [7, 15]
# training accuracy: 0.929724277067922
# training sensitivity: 0.38596491228070173
# training specificity: 0.9873558943845295
# [7, 20]
# training accuracy: 0.9295634920634921
# training sensitivity: 0.38275862068965516
# training specificity: 0.9875640087783467
# [7, 25]
# training accuracy: 0.929733246584255
# training sensitivity: 0.3843537414965986
# training specificity: 0.987410071942446
# [7, 30]
# training accuracy: 0.9295774647887324
# training sensitivity: 0.38333333333333336
# training specificity: 0.9876062322946175
# [7, 35]
# training accuracy: 0.9287964713295526
# training sensitivity: 0.3858520900321543
# training specificity: 0.9877750611246944
# [7, 40]
# training accuracy: 1.0324585635359116
# training sensitivity: 0.38782051282051283
# training specificity: 0.9879476584022039
# [8, 0]
# training accuracy: 0.9299442033477991
# training sensitivity: 0.38782051282051283
# training specificity: 0.9879890185312286
# [8, 5]
# training accuracy: 0.931013431013431
# training sensitivity: 0.38782051282051283
# training specificity: 0.988191632928475
# [8, 10]
# training accuracy: 0.931449188214071
# training sensitivity: 0.38924050632911394
# training specificity: 0.9883720930232558
# [8, 15]
# training accuracy: 0.9306872037914692
# training sensitivity: 0.38819875776397517
# training specificity: 0.9878847413228553
# [8, 20]
# training accuracy: 0.9308231173380035
# training sensitivity: 0.3902439024390244
# training specificity: 0.988056810845707
# [8, 25]
# training accuracy: 0.9309551208285386
# training sensitivity: 0.39156626506024095
# training specificity: 0.9879134860050891
# training sensitivity: 0.25
# training specificity: 1.0
# [0, 5]
# training accuracy: 0.85
# training sensitivity: 0.0
# training specificity: 0.9444444444444444
# [0, 10]
# training accuracy: 0.8636363636363636
# training sensitivity: 0.0
# training specificity: 0.9693877551020408
# [0, 15]
# training accuracy: 0.89375
# training sensitivity: 0.0
# training specificity: 0.9794520547945206
# [0, 20]
# training accuracy: 0.8761904761904762
# training sensitivity: 0.0
# training specificity: 0.983957219251337
# [0, 25]
# training accuracy: 0.8730769230769231
# training sensitivity: 0.0
# training specificity: 0.9869565217391304
# [0, 30]
# training accuracy: 0.8741935483870967
# training sensitivity: 0.07692307692307693
# training specificity: 0.988929889298893
# [0, 35]
# training accuracy: 0.8888888888888888
# training sensitivity: 0.0975609756097561
# training specificity: 0.9905956112852664
# [0, 40]
# training accuracy: 4.365853658536586
# training sensitivity: 0.08888888888888889
# training specificity: 0.9915966386554622
# [1, 0]
# training accuracy: 0.8907766990291263
# training sensitivity: 0.08695652173913043
# training specificity: 0.9918032786885246
# [1, 5]
# training accuracy: 0.8939393939393939
# training sensitivity: 0.08
# training specificity: 0.9927184466019418
# [1, 10]
# training accuracy: 0.89453125
# training sensitivity: 0.07272727272727272
# training specificity: 0.9934354485776805
# [1, 15]
# training accuracy: 0.8896797153024911
# training sensitivity: 0.078125
# training specificity: 0.9939759036144579
# [1, 20]
# training accuracy: 0.8937908496732027
# training sensitivity: 0.07462686567164178
# training specificity: 0.9944954128440368
# [1, 25]
# training accuracy: 0.8942598187311178
# training sensitivity: 0.0958904109589041
# training specificity: 0.9932088285229203
# [1, 30]
# training accuracy: 0.8960674157303371
# training sensitivity: 0.11392405063291139
# training specificity: 0.9936808846761453
# [1, 35]
# training accuracy: 0.8963254593175853
# ...
# training specificity: 0.9944933920704846
# [2, 25]
# training accuracy: 0.9201127819548872
# training sensitivity: 0.2803738317757009
# training specificity: 0.9916405433646813
# [2, 30]
# training accuracy: 0.9192100538599641
# training sensitivity: 0.27927927927927926
# training specificity: 0.9900299102691924
# [2, 35]
# training accuracy: 0.9218213058419243
# training sensitivity: 0.2894736842105263
# training specificity: 0.9904761904761905
# [2, 40]
# training accuracy: 1.257336343115124
# training sensitivity: 0.29914529914529914
# training specificity: 0.9908172635445363
# [3, 0]
# training accuracy: 0.9243421052631579
# training sensitivity: 0.29914529914529914
# training specificity: 0.9909008189262967
# [3, 5]
# training accuracy: 0.9249605055292259
# training sensitivity: 0.30578512396694213
# training specificity: 0.9903930131004367
# [3, 10]
# training accuracy: 0.9240121580547113
# training sensitivity: 0.30708661417322836
# training specificity: 0.9899074852817493
# [3, 15]
# training accuracy: 0.9238653001464129
# training sensitivity: 0.3106060606060606
# training specificity: 0.9894651539708266
# [3, 20]
# training accuracy: 0.923728813559322
# training sensitivity: 0.30656934306569344
# training specificity: 0.9898358092259578
# [3, 25]
# training accuracy: 0.9242837653478854
# training sensitivity: 0.32413793103448274
# training specificity: 0.9901589704769115
# [3, 30]
# training accuracy: 0.9261213720316622
# training sensitivity: 0.33557046979865773
# training specificity: 0.9904901243599122
# [3, 35]
# training accuracy: 0.9284802043422733
# training sensitivity: 0.34
# training specificity: 0.990819209039548
# [3, 40]
# training accuracy: 1.1576086956521738
# training sensitivity: 0.3333333333333333
# training specificity: 0.9910468319559229
# [4, 0]
# training accuracy: 0.927070457354759
# training sensitivity: 0.33121019108280253
# training specificity: 0.9911019849418207
# [4, 5]
# training accuracy: 0.9268585131894485
# training sensitivity: 0.3271604938271605
# training specificity: 0.9913678618857902
# [4, 10]
# training accuracy: 0.9278230500582072
# training sensitivity: 0.3313253012048193
# training specificity: 0.9916237113402062
# [4, 15]
# training accuracy: 0.9270361990950227
# training sensitivity: 0.32947976878612717
# training specificity: 0.9918495297805643
# [4, 20]
# training accuracy: 0.9273927392739274
# training sensitivity: 0.34615384615384615
# training specificity: 0.9920537897310513
# [4, 25]
# training accuracy: 0.9288008565310493
# training sensitivity: 0.3442622950819672
# training specificity: 0.9922848664688427
# [4, 30]
# training accuracy: 0.9285714285714286
# training sensitivity: 0.35106382978723405
# training specificity: 0.9913294797687862
# [4, 35]
# training accuracy: 0.9298780487804879
# training sensitivity: 0.35602094240837695
# training specificity: 0.9915588069780529
# [4, 40]
# training accuracy: 1.1053254437869822
# training sensitivity: 0.35384615384615387
# training specificity: 0.9911845730027549
# [5, 0]
# training accuracy: 0.9297029702970298
# training sensitivity: 0.35714285714285715
# training specificity: 0.9912280701754386
# [5, 5]
# training accuracy: 0.9304347826086956
# training sensitivity: 0.3712871287128713
# training specificity: 0.9908993576017131
# [5, 10]
# training accuracy: 0.9316037735849056
# training sensitivity: 0.38164251207729466
# training specificity: 0.9911134343962362
# [5, 15]
# training accuracy: 0.9327188940092166
# training sensitivity: 0.3827751196172249
# training specificity: 0.9913309535951046
# [5, 20]
# training accuracy: 0.9324324324324325
# training sensitivity: 0.37850467289719625
# training specificity: 0.9915254237288136
# [5, 25]
# training accuracy: 0.9325991189427313
# training sensitivity: 0.3761467889908257
# training specificity: 0.9917153996101364
# [5, 30]
# training accuracy: 0.9314655172413793
# training sensitivity: 0.3705357142857143
# training specificity: 0.9914122137404581
# [5, 35]
# training accuracy: 0.9312236286919832
# training sensitivity: 0.37117903930131
# training specificity: 0.9911256422232602
# [5, 40]
# training accuracy: 1.0731357552581262
# training sensitivity: 0.3717948717948718
# training specificity: 0.9908172635445363
# [6, 0]
# training accuracy: 0.930635838150289
# training sensitivity: 0.3728813559322034
# training specificity: 0.9908508691674291
# [6, 5]
# training accuracy: 0.9288025889967637
# training sensitivity: 0.36885245901639346
# training specificity: 0.9901256732495511
# [6, 10]
# training accuracy: 0.929024583663759
# training sensitivity: 0.3684210526315789
# training specificity: 0.9898901098901098
# [6, 15]
# training accuracy: 0.9280715396578538
# training sensitivity: 0.36470588235294116
# training specificity: 0.9900733707380233
# [6, 20]
# training accuracy: 0.9279176201372997
# training sensitivity: 0.3590733590733591
# training specificity: 0.9902666102412188
# [6, 25]
# training accuracy: 0.9285179640718563
# training sensitivity: 0.3612167300380228
# training specificity: 0.9904524699045247
# [6, 30]
# training accuracy: 0.9290962527553269
# training sensitivity: 0.3609022556390977
# training specificity: 0.9906351791530945
# [6, 35]
# training accuracy: 0.9296536796536796
# training sensitivity: 0.36764705882352944
# training specificity: 0.9908
# [6, 40]
# training accuracy: 1.04971932638332
# training sensitivity: 0.3663003663003663
# training specificity: 0.9909484454939
# [7, 0]
# training accuracy: 0.9302407932011332
# training sensitivity: 0.36496350364963503
# training specificity: 0.9909803921568627
# [7, 5]
# training accuracy: 0.9314544189283229
# training sensitivity: 0.37184115523465705
# training specificity: 0.9911436272622256
# [7, 10]
# training accuracy: 0.9309165526675787
# training sensitivity: 0.3710247349823322
# training specificity: 0.9909125331313896
# [7, 15]
# training accuracy: 0.9314055144586416
# training sensitivity: 0.3741258741258741
# training specificity: 0.9906994047619048
# [7, 20]
# training accuracy: 0.9315476190476191
# training sensitivity: 0.3758620689655172
# training specificity: 0.9904901243599122
# [7, 25]
# training accuracy: 0.9313597918022121
# training sensitivity: 0.375
# training specificity: 0.9906407487401008
# [7, 30]
# training accuracy: 0.9308578745198464
# training sensitivity: 0.37293729372937295
# training specificity: 0.9907834101382489
# [7, 35]
# training accuracy: 0.9306868304977945
# training sensitivity: 0.37540453074433655
# training specificity: 0.9905759162303664
# [7, 40]
# training accuracy: 1.0341850828729282
# training sensitivity: 0.3782051282051282
# training specificity: 0.9907024793388429
# [8, 0]
# training accuracy: 0.9314941103533788
# training sensitivity: 0.3821656050955414
# training specificity: 0.990728021978022
# [8, 5]
# training accuracy: 0.931929181929182
# training sensitivity: 0.3836477987421384
# training specificity: 0.9908722109533469
# [8, 10]
# training accuracy: 0.9326518340348767
# training sensitivity: 0.384375
# training specificity: 0.9910179640718563
# [8, 15]
# training accuracy: 0.9324644549763034
# training sensitivity: 0.3890577507598784
# training specificity: 0.9911388250738431
# [8, 20]
# training accuracy: 0.9319906596614127
# training sensitivity: 0.38622754491017963
# training specificity: 0.9909443725743855
# [8, 25]
# training accuracy: 0.9318181818181818
# training sensitivity: 0.3827893175074184
# training specificity: 0.9907613889773813
# [8, 30]
# training accuracy: 0.9327850255246739
# training sensitivity: 0.39002932551319647
# training specificity: 0.990894819466248
# [8, 35]
# training accuracy: 0.9328859060402684
# training sensitivity: 0.38953488372093026
# training specificity: 0.9907178217821783
# [8, 40]
# training accuracy: 1.0227410551849605
# training sensitivity: 0.38746438746438744
# training specificity: 0.9908172635445363
# [9, 0]
# training accuracy: 0.9324696802646086
# training sensitivity: 0.38746438746438744
# training specificity: 0.9908452853219408
# [9, 5]
# training accuracy: 0.9325720500271887
# training sensitivity: 0.384180790960452
# training specificity: 0.9909747292418772
# [9, 10]
# training accuracy: 0.9318669527896996
# training sensitivity: 0.38333333333333336
# training specificity: 0.9904988123515439
# [9, 15]
# training accuracy: 0.9311805187930122
# training sensitivity: 0.3787465940054496
# training specificity: 0.9906185869246555
# [9, 20]
# training accuracy: 0.9315569487983281
# training sensitivity: 0.38274932614555257
# training specificity: 0.9904541509979751
# [9, 25]
# training accuracy: 0.9314079422382672
# training sensitivity: 0.3803191489361702
# training specificity: 0.9905768132495717
# [9, 30]
# training accuracy: 0.9315173116089613
# training sensitivity: 0.3854166666666667
# training specificity: 0.9906884875846501
# [9, 35]
# training accuracy: 0.9318753142282554
# training sensitivity: 0.3850129198966408
# training specificity: 0.9908103592314118
# [9, 40]
# training accuracy: 1.012972972972973
# training sensitivity: 0.3871794871794872
# training specificity: 0.990909090909091
# [10, 0]
# training accuracy: 0.9325062034739454
# training sensitivity: 0.3871794871794872
# training specificity: 0.990934065934066
# [10, 5]
# training accuracy: 0.9323529411764706
# training sensitivity: 0.38734177215189874
# training specificity: 0.9907734056987788
# [10, 10]
# training accuracy: 0.9314769975786925
# training sensitivity: 0.38613861386138615
# training specificity: 0.990606548577563
# [10, 15]
# training accuracy: 0.9320574162679426
# training sensitivity: 0.39119804400978
# training specificity: 0.9907186422699549
# [10, 20]
# training accuracy: 0.9321513002364066
# training sensitivity: 0.38929440389294406
# training specificity: 0.99057344854674
# [10, 25]
# training accuracy: 0.9327102803738317
# training sensitivity: 0.3927710843373494
# training specificity: 0.9906856403622251
# [10, 30]
# training accuracy: 0.9327944572748268
# training sensitivity: 0.3914081145584726
# training specificity: 0.990795193045257
# [10, 35]
# training accuracy: 0.9328767123287671
# training sensitivity: 0.3915094339622642
# training specificity: 0.9908998988877654
# [10, 40]
# training accuracy: 1.0053632374451487
# training sensitivity: 0.38927738927738925
# training specificity: 0.990984222389181
# [11, 0]
# training accuracy: 0.9325361010830325
# training sensitivity: 0.3883720930232558
# training specificity: 0.9910044977511244
# [11, 5]
# training accuracy: 0.9323962516733602
# training sensitivity: 0.38850574712643676
# training specificity: 0.990857425253274
# [11, 10]
# training accuracy: 0.9324801412180053
# training sensitivity: 0.3900226757369615
# training specificity: 0.9909557565387436
# [11, 15]
# training accuracy: 0.932343954604976
# training sensitivity: 0.3887640449438202
# training specificity: 0.9908145999516558
# [11, 20]
# training accuracy: 0.9326424870466321
# training sensitivity: 0.3924611973392461
# training specificity: 0.9909112652475485
# [11, 25]
# training accuracy: 0.9329346433148227
# training sensitivity: 0.3934065934065934
# training specificity: 0.9910101726993139
# [11, 30]
# training accuracy: 0.9330092983939138
# training sensitivity: 0.39215686274509803
# training specificity: 0.9911069506201732
# [11, 35]
# training accuracy: 0.9330823923044751
# training sensitivity: 0.3930885529157667
# training specificity: 0.9909701319749942
# [11, 40]
# training accuracy: 0.9995559502664298
# training sensitivity: 0.3952991452991453
# training specificity: 0.9910468319559229
# [12, 0]
# training accuracy: 0.9333884981381878
# training sensitivity: 0.3952991452991453
# training specificity: 0.9910673385249656
# [12, 5]
# training accuracy: 0.9334561834561834
# training sensitivity: 0.3940677966101695
# training specificity: 0.9911604714415231
# [12, 10]
# training accuracy: 0.9335224969598703
# training sensitivity: 0.39285714285714285
# training specificity: 0.9912516823687753
# [12, 15]
# training accuracy: 0.9333868378812199
# training sensitivity: 0.3903966597077244
# training specificity: 0.9911209766925638
# [12, 20]
# training accuracy: 0.9334525228446563
# training sensitivity: 0.3925619834710744
# training specificity: 0.990989010989011
# [12, 25]
# training accuracy: 0.9335169158143194
# training sensitivity: 0.39263803680981596
# training specificity: 0.9910772578890098
# [12, 30]
# training accuracy: 0.9337748344370861
# training sensitivity: 0.3967611336032389
# training specificity: 0.990948275862069
# [12, 35]
# training accuracy: 0.9342206790123457
# training sensitivity: 0.40080160320641284
# training specificity: 0.9910352187833511
# [12, 40]
# training accuracy: 0.9947003668976763
# training sensitivity: 0.40039447731755423
# training specificity: 0.9910998092816274
# [13, 0]
# training accuracy: 0.9339190221543163
# training sensitivity: 0.40039447731755423
# training specificity: 0.9911186297314443
# [13, 5]
# training accuracy: 0.9339765418085509
# training sensitivity: 0.39921722113502933
# training specificity: 0.9912041884816754
# [13, 10]
# training accuracy: 0.934407796101949
# training sensitivity: 0.4027237354085603
# training specificity: 0.9910825383658233
# [13, 15]
# training accuracy: 0.934459710360193
# training sensitivity: 0.4049904030710173
# training specificity: 0.9911613566289825
# [13, 20]
# training accuracy: 0.9346946284032377
# training sensitivity: 0.40344168260038243
# training specificity: 0.9912477101567271
# [13, 25]
# training accuracy: 0.9347429821363471
# training sensitivity: 0.4056603773584906
# training specificity: 0.9913236481033091
# [13, 30]
# training accuracy: 0.9346098265895953
# training sensitivity: 0.40816326530612246
# training specificity: 0.9913948369021413
# [13, 35]
# training accuracy: 0.9344790547798066
# training sensitivity: 0.40850277264325324
# training specificity: 0.9908820614469772
# [13, 40]
# training accuracy: 0.9903918613413715
# training sensitivity: 0.40476190476190477
# training specificity: 0.9909484454939
# [14, 0]
# training accuracy: 0.9341965235899256
# training sensitivity: 0.40476190476190477
# training specificity: 0.9909662215239592
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-7e8b65cb6047> in <module>()
#      54         net.train()
#      55
# ---> 56         for i, data in enumerate(cs):
#      57             targets, inputs = data['target'],data['features']
#      58
#
# /anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     802
#     803             assert not self._shutdown and self._tasks_outstanding > 0
# --> 804             idx, data = self._get_data()
#     805             self._tasks_outstanding -= 1
#     806
#
# /anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#     769         else:
#     770             while True:
# --> 771                 success, data = self._try_get_data()
#     772                 if success:
#     773                     return data
#
# /anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     722         #   (bool: whether successfully get data, any: data if successful else None)
#     723         try:
# --> 724             data = self._data_queue.get(timeout=timeout)
#     725             return (True, data)
#     726         except Exception as e:
#
# /anaconda3/lib/python3.6/multiprocessing/queues.py in get(self, block, timeout)
#     102                 if block:
#     103                     timeout = deadline - time.time()
# --> 104                     if not self._poll(timeout):
#     105                         raise Empty
#     106                 elif not self._poll():
#
# /anaconda3/lib/python3.6/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /anaconda3/lib/python3.6/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# /anaconda3/lib/python3.6/multiprocessing/connection.py in wait(object_list, timeout)
#     909
#     910             while True:
# --> 911                 ready = selector.select(timeout)
#     912                 if ready:
#     913                     return [key.fileobj for (key, events) in ready]
#
# /anaconda3/lib/python3.6/selectors.py in select(self, timeout)
#     374             ready = []
#     375             try:
# --> 376                 fd_event_list = self._poll.poll(timeout)
#     377             except InterruptedError:
#     378                 return ready
#
# KeyboardInterrupt:
